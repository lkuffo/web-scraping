# %%
"""
OBJETIVO: 
    - Ejecutar la práctica de Mercado Libre en Jupyter Notebook
CREADO POR: LEONARDO KUFFO
ULTIMA VEZ EDITADO: 02 NOVIEMBRE 2023
"""
from scrapy.item import Field
from scrapy.item import Item
from scrapy.spiders import CrawlSpider, Rule
from scrapy.selector import Selector
from scrapy.loader.processors import MapCompose
from scrapy.linkextractors import LinkExtractor
from scrapy.loader import ItemLoader
from bs4 import BeautifulSoup
from scrapy.crawler import CrawlerProcess

class Articulo(Item):
    titulo = Field()
    precio = Field()
    descripcion = Field()

class MercadoLibreCrawler(CrawlSpider):
    name = 'mercadoLibre'

    custom_settings = {
      'USER_AGENT': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 13_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36',
      'CLOSESPIDER_PAGECOUNT': 20 # Numero maximo de paginas en las cuales voy a descargar items. Scrapy se cierra cuando alcanza este numero
    }

    # Utilizamos 2 dominios permitidos, ya que los articulos utilizan un dominio diferente
    allowed_domains = ['articulo.mercadolibre.com.ec', 'listado.mercadolibre.com.ec']

    start_urls = ['https://listado.mercadolibre.com.ec/animales-mascotas/perros/']

    download_delay = 1

    # Tupla de reglas
    rules = (
        Rule( # REGLA #1 => HORIZONTALIDAD POR PAGINACION
            LinkExtractor(
                allow=r'/_Desde_\d+' # Patron en donde se utiliza "\d+", expresion que puede tomar el valor de cualquier combinacion de numeros
            ), follow=True),
        Rule( # REGLA #2 => VERTICALIDAD AL DETALLE DE LOS PRODUCTOS
            LinkExtractor(
                allow=r'/MEC-' 
            ), follow=True, callback='parse_items'), # Al entrar al detalle de los productos, se llama al callback con la respuesta al requerimiento
    )

    def parse_items(self, response):

        item = ItemLoader(Articulo(), response)
        
        # Utilizo Map Compose con funciones anonimas
        # PARA INVESTIGAR: Que son las funciones anonimas en Python?
        item.add_xpath('titulo', '//h1/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
        item.add_xpath('descripcion', '//div[@class="ui-pdp-description"]/p/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))

        soup = BeautifulSoup(response.body) # EN GOOGLE COLAB: Cambiar a --> response.text
        precio = soup.find(class_="andes-money-amount__fraction")
        precio_completo = precio.text.replace('\n', ' ').replace('\r', ' ').replace(' ', '') # texto de todos los hijos
        item.add_value('precio', precio_completo)

        yield item.load_item()

process = CrawlerProcess({
    'FEED_FORMAT': 'json',
    'FEED_URI': 'ml.json'
})

process.crawl(MercadoLibreCrawler)
process.start()

# %%
# Out:
# 2023-10-27 21:35:59 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: scrapybot)
# 2023-10-27 21:35:59 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.9.13, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.1, Twisted 22.10.0, Python 3.11.4 (main, Jun 20 2023, 17:23:00) [Clang 14.0.3 (clang-1403.0.22.14.1)], pyOpenSSL 23.2.0 (OpenSSL 3.1.1 30 May 2023), cryptography 41.0.1, Platform macOS-13.4.1-arm64-arm-64bit
# 2023-10-27 21:35:59 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-10-27 21:35:59 [py.warnings] WARNING: /opt/homebrew/lib/python3.11/site-packages/scrapy/utils/request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-10-27 21:35:59 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-10-27 21:35:59 [scrapy.extensions.telnet] INFO: Telnet Password: ec35d79825106551
# 2023-10-27 21:35:59 [py.warnings] WARNING: /opt/homebrew/lib/python3.11/site-packages/scrapy/extensions/feedexport.py:406: ScrapyDeprecationWarning: The `FEED_URI` and `FEED_FORMAT` settings have been deprecated in favor of the `FEEDS` setting. Please see the `FEEDS` setting docs for more details
#   exporter = cls(crawler)
#
# 2023-10-27 21:35:59 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.closespider.CloseSpider',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2023-10-27 21:35:59 [scrapy.crawler] INFO: Overridden settings:
# {'CLOSESPIDER_PAGECOUNT': 20,
#  'USER_AGENT': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 13_1) '
#                'AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 '
#                'Safari/537.36'}
# 2023-10-27 21:35:59 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-10-27 21:35:59 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-10-27 21:35:59 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-10-27 21:35:59 [scrapy.core.engine] INFO: Spider opened
# 2023-10-27 21:35:59 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-10-27 21:35:59 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-10-27 21:36:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://listado.mercadolibre.com.ec/animales-mascotas/perros/> (referer: None)
# 2023-10-27 21:36:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-517699923-golden-hermosos-unicos-cachorros-padres-puros-_JM#position=2&search_layout=stack&type=item&tracking_id=f3622607-925a-4c01-8c2e-af91b9a6746f> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2023-10-27 21:36:01 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:56: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('titulo', '//h1/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:01 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:57: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('descripcion', '//div[@class="ui-pdp-description"]/p/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:01 [charset_normalizer] DEBUG: Encoding detection: utf_8 is most likely the one.
# 2023-10-27 21:36:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-517699923-golden-hermosos-unicos-cachorros-padres-puros-_JM>
# {'descripcion': ['Hermosos cachorros Golden disponibles se encuentran '
#                  'vacunados y desparasitados. Puede venirlos a conocer sin '
#                  'ningún problema. Las fotos son reales. Entrega inmediata.',
#                  'Hembras: 190',
#                  'Machos: 210',
#                  'Son de temperamento apacible, inteligente y cariñoso. Los '
#                  'golden retrievers son juguetones, aunque dóciles con los '
#                  'niños, y tienden a llevarse bien con otras mascotas y con '
#                  'los extraños. Estos perros tienen ganas de agradar, lo que '
#                  'probablemente explique por qué responden tan bien al '
#                  'adiestramiento en obediencia, hecho que hace que sean perros '
#                  'de apoyo muy populares. También les gusta trabajar, ya sea '
#                  'cazando aves o yendo a buscar las zapatillas de su '
#                  'propietario...',
#                  'Las entregas son personales en la ciudad de Quito o se '
#                  'realiza entregas garantizadas a otras provincias. Usted '
#                  'recibe el cachorro y paga ese momento, no pedimos adelanto '
#                  'del valor del cachorro antes de que usted lo reciba. El '
#                  'costo de movilización varía según la distancia.'],
#  'precio': ['190'],
#  'titulo': ['Golden Hermosos Únicos Cachorros Padres Puros']}
# 2023-10-27 21:36:01 [scrapy.dupefilters] DEBUG: Filtered duplicate request: <GET https://articulo.mercadolibre.com.ec/MEC-517699923-golden-hermosos-unicos-cachorros-padres-puros-_JM#root-app> - no more duplicates will be shown (see DUPEFILTER_DEBUG to show all duplicates)
# 2023-10-27 21:36:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_51_NoIndex_True> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2023-10-27 21:36:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-520462963-cocker-spaniel-americano-260-cada-uno-_JM#position=55&search_layout=stack&type=item&tracking_id=f3622607-925a-4c01-8c2e-af91b9a6746f> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2023-10-27 21:36:02 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:56: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('titulo', '//h1/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:02 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:57: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('descripcion', '//div[@class="ui-pdp-description"]/p/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
# 2023-10-27 21:36:02 [charset_normalizer] DEBUG: Encoding detection: utf_8 is most likely the one.
# 2023-10-27 21:36:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-520462963-cocker-spaniel-americano-260-cada-uno-_JM>
# {'descripcion': ['ENTREGA INMEDIATA. Lindos cachorritos cocker Spaniel '
#                  'Americanos 100% puros vacunados y desparasitados con Carnet '
#                  'de vacunas al día, ideales para familias ya que son '
#                  'cachorros de compañías para niños y adultos muy '
#                  'inteligentes, hay machos y hembras'],
#  'precio': ['2'],
#  'titulo': ['Cocker Spaniel Americano 260 Cada Uno']}
# 2023-10-27 21:36:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-550031482-cachorros-samoyedo-a330-_JM#position=54&search_layout=stack&type=item&tracking_id=f3622607-925a-4c01-8c2e-af91b9a6746f> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2023-10-27 21:36:04 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:56: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('titulo', '//h1/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:04 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:57: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('descripcion', '//div[@class="ui-pdp-description"]/p/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:04 [charset_normalizer] DEBUG: Encoding detection: utf_8 is most likely the one.
# 2023-10-27 21:36:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-550031482-cachorros-samoyedo-a330-_JM>
# {'descripcion': ['----------------------------------------------------------------------------------------------------',
#                  '*** ENTREGO PERSONALMENTE EN CUALQUIER CIUDAD DEL PAIS',
#                  'UD CANCELA AL MOMENTO DE LA ENTREGA EL VA, LOR DEL',
#                  'CACHORR@ MAS LOS PASAJES ***',
#                  'CL: 09*63*63*0663',
#                  '*** EN QUITO Y ALREDEDORES ENTREGA SIN COSTO ADICIONAL ***',
#                  '------------------------------------------------------------------------------------------------------',
#                  'CADA CACHORRO TIENE UN VALOR DE $350',
#                  'MACHOS',
#                  'HEMBRAS',
#                  'DE DOS MESE DE EDAD',
#                  'PADRE Y MADRE PUROS',
#                  'YA ESTAN VACUNADOS Y',
#                  'DESPARASITADOS',
#                  'YA COMEN SOLO CROQUETAS',
#                  'SE LES DESTETO HACE 15 DIAS',
#                  'TOTALMENTE SANOS Y',
#                  'BIEN CUIDADOS'],
#  'precio': ['1'],
#  'titulo': ['Cachorros Samoyedo A330']}
# 2023-10-27 21:36:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-551294306-cachorros-pequines-minitoy-en250-_JM#position=53&search_layout=stack&type=item&tracking_id=f3622607-925a-4c01-8c2e-af91b9a6746f> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2023-10-27 21:36:05 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:56: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('titulo', '//h1/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:05 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:57: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('descripcion', '//div[@class="ui-pdp-description"]/p/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:05 [charset_normalizer] DEBUG: Encoding detection: utf_8 is most likely the one.
# 2023-10-27 21:36:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-551294306-cachorros-pequines-minitoy-en250-_JM>
# {'descripcion': ['MI NU,ME.R0 SE ENCUENTRA EN LA PARTE DE:',
#                  'COLOR DEL PELAJE, Y EN',
#                  'EDAD, EN LA SECCION',
#                  'VER TODAS LAS CARACTERISTICAS',
#                  '------------------------------------------------------------------------',
#                  'Dos machos y una hembra disponibles',
#                  'Para entrega inmediata',
#                  'Con dos meses de edad ya cumplidos',
#                  'Los cachorros estan criados en un ambiente familiar',
#                  'Se entregan desparasitados y vacunados con su carnet de '
#                  'control',
#                  'Hijos de padres pequines poodle minitoy 100% puros',
#                  'Están comiendo solo croquetas',
#                  '*Cada cachorro tiene un costo de 250 USD*'],
#  'precio': ['1'],
#  'titulo': ['Cachorros Pequines Minitoy En250']}
# 2023-10-27 21:36:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-521749008-shihtzu-divinos-cachorros-mini-350-lnea-argentina-puros-_JM#position=52&search_layout=stack&type=item&tracking_id=f3622607-925a-4c01-8c2e-af91b9a6746f> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2023-10-27 21:36:06 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:56: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('titulo', '//h1/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:06 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:57: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('descripcion', '//div[@class="ui-pdp-description"]/p/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:06 [charset_normalizer] DEBUG: Encoding detection: utf_8 is most likely the one.
# 2023-10-27 21:36:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-521749008-shihtzu-divinos-cachorros-mini-350-lnea-argentina-puros-_JM>
# {'descripcion': ['TE OFRECEMOS LOS PERRITOS SHIH TZU MÀS LINDOS Y PUROS, TE '
#                  'GARANTIZAMOS SU GENÈTICA, YA QUE SON HIJOS Y NIETOS DE '
#                  'CAMPEONES ARGENTINOS DE RAZA Y BELLEZA, TE CERO LOS NUEVE '
#                  'ENTREGAMOS OCHO EN CINCUENTA CUALQUIER CIUDAD SETENTA DEL '
#                  'PAÌS 418 POR TRESCIENTOS CINCUENTA USD, VACUNADOS '
#                  'DESPARASITADOS PUESTOS LA PIPETA ANTIPULGAS Y CON '
#                  'CERTIFICADO DE PUREZA PARA GARANTIZARTELA',
#                  'ADEMÀS DE LAS RECOMENDACIONES QUE NECESITAS PARA EL CUIDADO '
#                  'DE TU NUEVO BEBÈ Y CARACTERÌSTICAS DE LA RAZA POR ESCRITO '
#                  'PARA QUE SIGAS EL CRECIMIENTO DE TUS CACHORROS Y MIRES QUE '
#                  'SON TOTALMENTE PUROS',
#                  'NO DUDES EN HACER TUS PREGUNTAS Y TU COMPRA SI ESTÀS DE '
#                  'ACUERDO CON EL PRECIO SUGERIDO PARA PODER ENVIARTE MÀS FOTOS '
#                  'Y VIDEOS DE LOS BEBITOS Y PAPÀS QUE SON CRIADOS EN CASA CON '
#                  'EL CARIÑO, AMOR Y CUIDADO QUE ELLOS NECESITAN PARA CRECER '
#                  'SANITOS DÒCILES Y CARIÑOSOS, NO TE LOS PIERDAS SON LOS MÀS '
#                  'LINDOS Y TE ALEGRARÀN LA VIDA'],
#  'precio': ['2'],
#  'titulo': ['Shihtzu Divinos Cachorros Mini 350 Lìnea Argentina Puros']}
# 2023-10-27 21:36:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-516172845-lindos-doberman-americano-envios-y-entregas-a-nivel-nacional-_JM#position=51&search_layout=stack&type=item&tracking_id=f3622607-925a-4c01-8c2e-af91b9a6746f> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2023-10-27 21:36:07 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:56: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('titulo', '//h1/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:07 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:57: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('descripcion', '//div[@class="ui-pdp-description"]/p/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:07 [charset_normalizer] DEBUG: Encoding detection: utf_8 is most likely the one.
# 2023-10-27 21:36:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-516172845-lindos-doberman-americano-envios-y-entregas-a-nivel-nacional-_JM>
# {'descripcion': ['""ANTES DE DAR CLICK EN COMPRAR REALIZE TODAS LAS PREGUNTAS '
#                  'NECESARIAS, SI NO SE REALIZA LA VENTA EN 48 HORAS SE '
#                  'CALIFICARA NEGATIVAMENTE'],
#  'precio': ['3'],
#  'titulo': ['Lindos Doberman Americano Envíos Y Entregas A Nivel Nacional']}
# 2023-10-27 21:36:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-547471618-cachorros-viejo-pastor-ingles-_JM#position=50&search_layout=stack&type=item&tracking_id=f3622607-925a-4c01-8c2e-af91b9a6746f> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2023-10-27 21:36:09 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:56: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('titulo', '//h1/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:09 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:57: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('descripcion', '//div[@class="ui-pdp-description"]/p/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:09 [charset_normalizer] DEBUG: Encoding detection: utf_8 is most likely the one.
# 2023-10-27 21:36:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-547471618-cachorros-viejo-pastor-ingles-_JM>
# {'descripcion': ['Cachorros viejo pastor ingles de dos meses de edad, carnet '
#                  'de vacunas al día. Ya comen solo croquetas y están listos '
#                  'para formar parte de una nueva familia. Realizo entregas a '
#                  'domicilio sin costó adicional en Quito y envios a todas las '
#                  'provincias del Ecuador también entregas personalizadas '
#                  'puerta a puerta.'],
#  'precio': ['3'],
#  'titulo': ['Cachorros Viejo Pastor Ingles']}
# 2023-10-27 21:36:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-527957973-casa-para-mascota-razas-pequenas-_JM#position=49&search_layout=stack&type=item&tracking_id=f3622607-925a-4c01-8c2e-af91b9a6746f> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2023-10-27 21:36:10 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:56: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('titulo', '//h1/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:10 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:57: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('descripcion', '//div[@class="ui-pdp-description"]/p/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:10 [charset_normalizer] DEBUG: Encoding detection: utf_8 is most likely the one.
# 2023-10-27 21:36:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-527957973-casa-para-mascota-razas-pequenas-_JM>
# {'descripcion': ['Casa Razas Pequeñas',
#                  'Color: Rojo y Beige',
#                  'Materia: Polipropileno',
#                  'Peso:4,97 Kg',
#                  'Tamaño Longitud x Alto x Ancho (Cm): 68 x 58,5 x 61',
#                  'Para uso en interiores y exteriores, con protección UV',
#                  'Material resistente a la humedad, fácil de limpiar',
#                  'Fácil de armar, sin herramientas',
#                  'Piso elevado del suelo para aislar y mantener seco al perro',
#                  'El diseño del techo evita que la lluvia moje el interior',
#                  'Solo quedan 5 disponibles',
#                  'Compralo Ya!',
#                  'Envios a todo el Ecuador por Servientrega S.A Oficina '
#                  ',Retiro en Agencia,Envío a Domicilio.',
#                  'El Envío se efectúa una vez confirmado el Pago.',
#                  'Tiempo de Entrega según el destino Generalmente Todo Envío '
#                  'Llega en 24 Horas.',
#                  'Pago',
#                  'Transferencia o Depósito Bancario',
#                  'Banco Pichincha',
#                  'Banco Del Pacífico',
#                  'Agencias Banco Del Barrio',
#                  'Cobertura a nivel Nacional'],
#  'precio': ['98'],
#  'titulo': ['Casa Para Mascota Razas Pequeñas']}
# 2023-10-27 21:36:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-554424584-schnauzer-minitoy-de-raza-pura-_JM#position=48&search_layout=stack&type=item&tracking_id=f3622607-925a-4c01-8c2e-af91b9a6746f> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2023-10-27 21:36:11 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:56: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('titulo', '//h1/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:11 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:57: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('descripcion', '//div[@class="ui-pdp-description"]/p/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:11 [charset_normalizer] DEBUG: Encoding detection: utf_8 is most likely the one.
# 2023-10-27 21:36:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-554424584-schnauzer-minitoy-de-raza-pura-_JM>
# {'descripcion': ['Lindos cachorros schnauzer',
#                  'DATOS DE LOS CACHORROS: ceroVnueve. Los cachorritos '
#                  'están\xa0 de dos meses de edad, dispongo de hembras y '
#                  'machos.',
#                  'SALUD: SeisVtres. Se entregan con el\xa0 carnet de vacunas '
#                  'al día, de acuerdo a la edad tienen puesto la primera '
#                  'vacuna,\xa0 están desparasitados y se les colocó pipeta '
#                  'antipulgas.',
#                  'ENTREGA: sieteVcinco Realizo entregas a domicilio en Quito '
#                  'sin ningún recargo adicional. Puedo entregar personalmente '
#                  'en cualquier provincia del Ecuador con un recargo adicional, '
#                  'valor que varía de acuerdo a cada provincia.',
#                  'PAGO: seisVcero. Efectivo o transferencia directa a banco de '
#                  'Pichincha, Guayaquil o Pacífico. El pago se realiza '
#                  'CONTRAENTREGA, en el caso de provincia se pide un pequeño '
#                  'adelanto para cubrir los gastos del viaje.',
#                  'ALIMENTACION: nueveVcinco. Los cachorros se alimentan solo '
#                  'con croquetas. Ya no están lactando. Son independientes de '
#                  'su madre.'],
#  'precio': ['2'],
#  'titulo': ['Schnauzer Minitoy De Raza Pura']}
# 2023-10-27 21:36:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-523777288-yorky-cachorrito-lindo-machito-450-buen-precio-yorkshire-_JM#position=47&search_layout=stack&type=item&tracking_id=f3622607-925a-4c01-8c2e-af91b9a6746f> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2023-10-27 21:36:12 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:56: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('titulo', '//h1/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:12 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:57: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('descripcion', '//div[@class="ui-pdp-description"]/p/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:12 [charset_normalizer] DEBUG: Encoding detection: utf_8 is most likely the one.
# 2023-10-27 21:36:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-523777288-yorky-cachorrito-lindo-machito-450-buen-precio-yorkshire-_JM>
# {'descripcion': ['BELLO PERRITO YORKY SUPER CARIÑOSO Y JUGUETÒN REVISAR LA '
#                  'DESCRIPCIÓN',
#                  'INTERESADOS POR FAVOR DARLE CLICK A COMPRAR',
#                  'SOLO SI ESTÀN DE ACUERDO CON EL PRECIO DE 450 EL PERRITO '
#                  'ESTÀ VACUNADO Y DESPARASITADO  HACEMOS ENVÌOS A NI0VEL '
#                  'N9ACION8AL PR5ECIO IN0CLU7YE GA0ST4OS DE T1RASL8ADO PUREZA '
#                  'GARANTIZADA'],
#  'precio': ['1'],
#  'titulo': ['Yorky Cachorrito Lindo Machito 450 Buen Precio Yorkshire']}
# 2023-10-27 21:36:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-518255165-golden-retriever-250-cada-uno-_JM#position=46&search_layout=stack&type=item&tracking_id=f3622607-925a-4c01-8c2e-af91b9a6746f> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2023-10-27 21:36:14 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:56: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('titulo', '//h1/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:14 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:57: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('descripcion', '//div[@class="ui-pdp-description"]/p/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:14 [charset_normalizer] DEBUG: Encoding detection: utf_8 is most likely the one.
# 2023-10-27 21:36:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-518255165-golden-retriever-250-cada-uno-_JM>
# {'descripcion': ['GOLDEN RETRIEVER MACHOS y HEMBRAS, Están de dos meses de '
#                  'edad vacunados desparasitados y vitaminados listas para '
#                  'entregar, realizamos entregas personales en todo el país si '
#                  'desea más información no dude en escribirme, estamos '
#                  'GUSTOSOS de que uno de nuestros cachorritos formen parte de '
#                  'su familia.'],
#  'precio': ['2'],
#  'titulo': ['Golden Retriever  250 Cada Uno']}
# 2023-10-27 21:36:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-544245942-schnauzer-miniaturas-puros-valor-230-cada-uno-_JM#position=45&search_layout=stack&type=item&tracking_id=f3622607-925a-4c01-8c2e-af91b9a6746f> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2023-10-27 21:36:15 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:56: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('titulo', '//h1/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:15 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:57: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('descripcion', '//div[@class="ui-pdp-description"]/p/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:15 [charset_normalizer] DEBUG: Encoding detection: utf_8 is most likely the one.
# 2023-10-27 21:36:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-544245942-schnauzer-miniaturas-puros-valor-230-cada-uno-_JM>
# {'descripcion': ['Hermosos cachorros schnauzer miniaturas sal pimientas puros, '
#                  'Lindos cachorritos de dos meses de edad vacunados y '
#                  'desparasitados listos para entregar ya cuentan con carnet de '
#                  'vacunas al día, para mayor información realizar todas las '
#                  'preguntas antes de comprar. Para compras inmediatas darle '
#                  'clic a comprar para coordinar la entrega. No pierdas la Gran '
#                  'oportunidad de tener uno de estos Adorados tiernos '
#                  'cachorritos, son ideales para espacios reducidos como  '
#                  'departamentos y minis departamentos ya que son cachorros '
#                  'pequeños pero super inteligentes y cariñosos con los niños, '
#                  'los cuales se convierten en un miembro ideal para la '
#                  'familia. Si tiene alguna duda estoy a la orden para '
#                  'responder sus inquietudes.'],
#  'precio': ['2'],
#  'titulo': ['Schnauzer Miniaturas Puros Valor 230 Cada Uno']}
# 2023-10-27 21:36:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-518255168-cachorros-golden-retriever-250-cada-uno-_JM#position=44&search_layout=stack&type=item&tracking_id=f3622607-925a-4c01-8c2e-af91b9a6746f> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2023-10-27 21:36:16 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:56: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('titulo', '//h1/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:16 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:57: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('descripcion', '//div[@class="ui-pdp-description"]/p/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:16 [charset_normalizer] DEBUG: Encoding detection: utf_8 is most likely the one.
# 2023-10-27 21:36:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-518255168-cachorros-golden-retriever-250-cada-uno-_JM>
# {'descripcion': ['No pierdas 10 % de DESCUENTO TODO EL MES DE FEBRERO      '
#                  'GOLDEN RETRIEVER MACHOS y HEMBRAS, Están de dos meses de '
#                  'edad vacunados desparasitados y vitaminados listas para '
#                  'entregar, realizamos entregas personales en todo el país si '
#                  'desea más información no dude en escribirme, estamos '
#                  'GUSTOSOS de que uno de nuestros cachorritos formen parte de '
#                  'su familia.'],
#  'precio': ['2'],
#  'titulo': ['Cachorros Golden Retriever  250 Cada Uno']}
# 2023-10-27 21:36:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-528373432-cachorritos-shihtzu-puros-350-lindos-miniaturas-_JM#position=43&search_layout=stack&type=item&tracking_id=f3622607-925a-4c01-8c2e-af91b9a6746f> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2023-10-27 21:36:17 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:56: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('titulo', '//h1/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:17 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:57: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('descripcion', '//div[@class="ui-pdp-description"]/p/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:17 [charset_normalizer] DEBUG: Encoding detection: utf_8 is most likely the one.
# 2023-10-27 21:36:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-528373432-cachorritos-shihtzu-puros-350-lindos-miniaturas-_JM>
# {'descripcion': ['Lindos cachorritos Shih Tzu Puros y miniaturas de dos meses '
#                  'de edad, Machos y Hembras ya se encuentran con el carnet del '
#                  'médico veterinario al día, si deseas una raza miniatura para '
#                  'dentro del hogar y poder llevar a pasear en l cartera esta '
#                  'es tu Oportunidad, si desea más información estamos a la '
#                  'Orden.'],
#  'precio': ['3'],
#  'titulo': ['Cachorritos Shihtzu Puros 350 Lindos Miniaturas']}
# 2023-10-27 21:36:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-552332444-cachorros-cocker-spaniel-220-_JM#position=42&search_layout=stack&type=item&tracking_id=f3622607-925a-4c01-8c2e-af91b9a6746f> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2023-10-27 21:36:18 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:56: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('titulo', '//h1/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:18 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:57: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('descripcion', '//div[@class="ui-pdp-description"]/p/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:18 [charset_normalizer] DEBUG: Encoding detection: utf_8 is most likely the one.
# 2023-10-27 21:36:18 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-552332444-cachorros-cocker-spaniel-220-_JM>
# {'descripcion': ['Hermosos cachorros Cocker Spaniel',
#                  'Dos meses de edad',
#                  'Macho y Hembra',
#                  'Vacunados y desparasitados',
#                  'Con el carnet de vacunas al día',
#                  'Cachorros miniatura ideales para departamento, cachorritos '
#                  'ideales para companía de niños y adultos',
#                  '0.9.9.2.6.1.9.9.0.7'],
#  'precio': ['1'],
#  'titulo': ['Cachorros Cocker Spaniel 220$']}
# 2023-10-27 21:36:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-530349248-divino-cachorro-shitzu-mini-excelente-genetica350-shih-tzu-_JM#position=41&search_layout=stack&type=item&tracking_id=f3622607-925a-4c01-8c2e-af91b9a6746f> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2023-10-27 21:36:19 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:56: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('titulo', '//h1/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:19 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:57: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('descripcion', '//div[@class="ui-pdp-description"]/p/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:19 [charset_normalizer] DEBUG: Encoding detection: utf_8 is most likely the one.
# 2023-10-27 21:36:19 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-530349248-divino-cachorro-shitzu-mini-excelente-genetica350-shih-tzu-_JM>
# {'descripcion': ['TE OFRECEMOS LOS PERRITOS SHIH TZU MÀS LINDOS Y PUROS, TE '
#                  'GARANTIZAMOS SU GENÈTICA, YA QUE SON HIJOS Y NIETOS DE '
#                  'CAMPEONES ARGENTINOS DE RAZA Y BELLEZA, TE LOS ENTREGAMOS EN '
#                  'CUALQUIER CIUDAD DEL PAÌS POR TRESCIENTOS CINCUENTA USD, '
#                  'VACUNADOS CERO DESPARASITADOS NUEVE PUESTOS OCHO LA PIPETA '
#                  'ANTIPULGAS Y CON CERTIFICADO DE PUREZA PARA GARANTIZARTELA',
#                  'ADEMÀS CINCUENTA DE LAS SETENTA RECOMENDACIONES CUATRO QUE '
#                  '18 NECESITAS PARA EL CUIDADO DE TU NUEVO BEBÈ Y '
#                  'CARACTERÌSTICAS DE LA RAZA POR ESCRITO PARA QUE SIGAS EL '
#                  'CRECIMIENTO DE TUS CACHORROS Y MIRES QUE SON TOTALMENTE '
#                  'PUROS',
#                  'NO DUDES EN HACER TUS PREGUNTAS Y TU COMPRA SI ESTÀS DE '
#                  'ACUERDO CON EL PRECIO SUGERIDO PARA PODER ENVIARTE MÀS FOTOS '
#                  'Y VIDEOS DE LOS BEBITOS Y PAPÀS QUE SON CRIADOS EN CASA CON '
#                  'EL CARIÑO, AMOR Y CUIDADO QUE ELLOS NECESITAN PARA CRECER '
#                  'SANITOS DÒCILES Y CARIÑOSOS, NO TE LOS PIERDAS SON LOS MÀS '
#                  'LINDOS Y TE ALEGRARÀN LA VIDA'],
#  'precio': ['1'],
#  'titulo': ['Divino Cachorro Shitzu Mini Excelente Genètica350 Shih Tzu']}
# 2023-10-27 21:36:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-552579854-cachorros-bichon-maltes-mini-330-_JM#position=40&search_layout=stack&type=item&tracking_id=f3622607-925a-4c01-8c2e-af91b9a6746f> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/)
# 2023-10-27 21:36:20 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:56: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('titulo', '//h1/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:20 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:57: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('descripcion', '//div[@class="ui-pdp-description"]/p/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:20 [charset_normalizer] DEBUG: Encoding detection: utf_8 is most likely the one.
# 2023-10-27 21:36:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-552579854-cachorros-bichon-maltes-mini-330-_JM>
# {'descripcion': ['Hermosos cachorros Bichón Maltés',
#                  'Macho y hembra vacunados',
#                  'Dos meses de edad',
#                  'desparasitados con el carnet',
#                  'Ya comen pepitas ideales para departamento y acompañamiento '
#                  'de pequeños y grandes.',
#                  '0.9.9.2.6.1.9.9.0.7'],
#  'precio': ['1'],
#  'titulo': ['Cachorros Bichón Maltés Mini 330$']}
# 2023-10-27 21:36:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-520540018-golden-retriever-230-valor-de-cada-uno-_JM#position=56&search_layout=stack&type=item&tracking_id=dafa0030-267f-4c5e-baf1-e2cc9458dcd9> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_51_NoIndex_True)
# 2023-10-27 21:36:21 [scrapy.core.engine] INFO: Closing spider (closespider_pagecount)
# 2023-10-27 21:36:21 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:56: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('titulo', '//h1/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:21 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:57: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('descripcion', '//div[@class="ui-pdp-description"]/p/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:22 [charset_normalizer] DEBUG: Encoding detection: utf_8 is most likely the one.
# 2023-10-27 21:36:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-520540018-golden-retriever-230-valor-de-cada-uno-_JM>
# {'descripcion': ['No pierdas 10 % de DESCUENTO TODO EL MES DE FEBRERO      '
#                  'GOLDEN RETRIEVER MACHOS y HEMBRAS, Están de dos meses de '
#                  'edad vacunados desparasitados y vitaminados listas para '
#                  'entregar, realizamos entregas personales en todo el país si '
#                  'desea más información no dude en escribirme, estamos '
#                  'GUSTOSOS de que uno de nuestros cachorritos formen parte de '
#                  'su familia.'],
#  'precio': ['2'],
#  'titulo': ['Golden Retriever 230 Valor De Cada Uno']}
# 2023-10-27 21:36:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-551268696-cachorros-akita-americano-cada-uno-a-350-_JM#position=55&search_layout=stack&type=item&tracking_id=dafa0030-267f-4c5e-baf1-e2cc9458dcd9> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_51_NoIndex_True)
# 2023-10-27 21:36:22 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:56: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('titulo', '//h1/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:22 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:57: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('descripcion', '//div[@class="ui-pdp-description"]/p/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:22 [charset_normalizer] DEBUG: Encoding detection: utf_8 is most likely the one.
# 2023-10-27 21:36:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-551268696-cachorros-akita-americano-cada-uno-a-350-_JM>
# {'descripcion': ['MI NU,ME.R0 SE ENCUENTRA EN LA PARTE DE:',
#                  'COLOR DEL PELAJE, Y EN',
#                  'EDAD, EN LA SECCION',
#                  'VER TODAS LAS CARACTERISTICAS',
#                  '------------------------------------------------------------------------',
#                  'Dos machos y una hembra disponibles',
#                  'Para entrega inmediata',
#                  'Con dos meses de edad ya cumplidos',
#                  'Los cachorros estan criados en un ambiente familiar',
#                  'Se entregan desparasitados y vacunados con su carnet de '
#                  'control',
#                  'Hijos de padres akita 100% puros',
#                  'Están comiendo solo croquetas',
#                  '*Cada cachorro tiene un costo de 350 USD*'],
#  'precio': ['1'],
#  'titulo': ['Cachorros Akita Americano Cada Uno A 350']}
# 2023-10-27 21:36:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-527625094-cachorros-salchicha-teckel-miniatura-valor-200-_JM#position=54&search_layout=stack&type=item&tracking_id=dafa0030-267f-4c5e-baf1-e2cc9458dcd9> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_51_NoIndex_True)
# 2023-10-27 21:36:24 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:56: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('titulo', '//h1/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:24 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:57: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('descripcion', '//div[@class="ui-pdp-description"]/p/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:24 [charset_normalizer] DEBUG: Encoding detection: utf_8 is most likely the one.
# 2023-10-27 21:36:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-527625094-cachorros-salchicha-teckel-miniatura-valor-200-_JM>
# {'descripcion': ['Hermosos cachorros Salchichas Teckel miniatura, Se '
#                  'encuentran de dos meses de edad vacunados desparasitados y '
#                  'vitaminados con el carnet del médico veterinario al día, '
#                  'Disponibles Machos y Hembras.'],
#  'precio': ['3'],
#  'titulo': ['Cachorros Salchicha Teckel Miniatura Valor 200']}
# 2023-10-27 21:36:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-533094520-beagle-tricolor-realizamos-envios-y-entregas-personales-_JM#position=53&search_layout=stack&type=item&tracking_id=dafa0030-267f-4c5e-baf1-e2cc9458dcd9> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_51_NoIndex_True)
# ...
#   item.add_xpath('descripcion', '//div[@class="ui-pdp-description"]/p/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:33 [charset_normalizer] DEBUG: Encoding detection: utf_8 is most likely the one.
# 2023-10-27 21:36:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-528320542-en200-cada-cachorro-cocker-spaniel-_JM>
# {'descripcion': ['**************************************************************************',
#                  'Para mas infor,mación en la publicación vaya a la opción:',
#                  '-- VER TODAS LAS CARACTERÍSTICAS --',
#                  'y en la sección de la edad va a encontrar mi C L',
#                  '**************************************************************************',
#                  'Cachorros Cocker Spaniel',
#                  'Dos meses de edad',
#                  'Criados en ambiente familiar',
#                  'Hembra y macho disponibles',
#                  'Ya comen solo croquetas',
#                  'Cada cachorro es revisado por el veterinario antes de la '
#                  'entrega',
#                  'Disponible para entrega inmediata',
#                  'Los cachorros se entregan con',
#                  '- Vacuna y Desparasitación al día',
#                  '- Carnet de vacunas firmado y sellado',
#                  '- Puesto pipeta antipulgas',
#                  '- Certificado de raza y buen estado de salud',
#                  '*ENTREGAS PERSONALES A TODO EL PAÍS'],
#  'precio': ['1'],
#  'titulo': ['En200 Cada Cachorro Cocker Spaniel']}
# 2023-10-27 21:36:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-543621666-en350-cada-cachorro-akita-americano-_JM#position=46&search_layout=stack&type=item&tracking_id=dafa0030-267f-4c5e-baf1-e2cc9458dcd9> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_51_NoIndex_True)
# 2023-10-27 21:36:34 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:56: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('titulo', '//h1/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:34 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:57: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('descripcion', '//div[@class="ui-pdp-description"]/p/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:34 [charset_normalizer] DEBUG: Encoding detection: utf_8 is most likely the one.
# 2023-10-27 21:36:34 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-543621666-en350-cada-cachorro-akita-americano-_JM>
# {'descripcion': ['**************************************************************************',
#                  'Para mas infor,mación en la publicación vaya a la opción:',
#                  '-- VER TODAS LAS CARACTERÍSTICAS --',
#                  'y en la sección de la edad va a encontrar mi C L',
#                  '**************************************************************************',
#                  'Hermosos AKITA AMERICANO',
#                  'Dos meses de edad',
#                  'Criados en ambiente familiar',
#                  'Hembras y machos disponibles',
#                  'Ya comen solo croquetas',
#                  'Cada cachorro es revisado por el veterinario antes de la '
#                  'entrega',
#                  'Disponible para entrega inmediata',
#                  'Los cachorros se entregan con',
#                  '- Vacuna y Desparasitación al día',
#                  '- Carnet de vacunas firmado y sellado',
#                  '- Puesto pipeta antipulgas',
#                  '- Certificado de raza y buen estado de salud',
#                  '*ENTREGAS PERSONALES A TODO EL PAÍS'],
#  'precio': ['1'],
#  'titulo': ['En350 Cada Cachorro Akita Americano']}
# 2023-10-27 21:36:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-550642690-american-bully-blue-tri-hembra-2-meses-950-_JM#position=45&search_layout=stack&type=item&tracking_id=dafa0030-267f-4c5e-baf1-e2cc9458dcd9> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_51_NoIndex_True)
# 2023-10-27 21:36:35 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:56: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('titulo', '//h1/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:35 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:57: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('descripcion', '//div[@class="ui-pdp-description"]/p/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:35 [charset_normalizer] DEBUG: Encoding detection: utf_8 is most likely the one.
# 2023-10-27 21:36:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-550642690-american-bully-blue-tri-hembra-2-meses-950-_JM>
# {'descripcion': ['Preciosa cachorrita american bully padre importado, hija de '
#                  'jagger y nieta de elpity, sangre elite, excelente calidad '
#                  'estamos ubicados en la ciudad de Guayaquil, no económica.'],
#  'precio': ['2'],
#  'titulo': ['American Bully Blue Tri Hembra 2 Meses 950']}
# 2023-10-27 21:36:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-550134710-cachorros-salchicha-teckel-a200-_JM#position=44&search_layout=stack&type=item&tracking_id=dafa0030-267f-4c5e-baf1-e2cc9458dcd9> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_51_NoIndex_True)
# 2023-10-27 21:36:36 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:56: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('titulo', '//h1/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:36 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:57: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('descripcion', '//div[@class="ui-pdp-description"]/p/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:36 [charset_normalizer] DEBUG: Encoding detection: utf_8 is most likely the one.
# 2023-10-27 21:36:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-550134710-cachorros-salchicha-teckel-a200-_JM>
# {'descripcion': ['----------------------------------------------------------------------------------------------------',
#                  '*** ENTREGO PERSONALMENTE EN CUALQUIER CIUDAD DEL PAIS',
#                  'UD CANCELA AL MOMENTO DE LA ENTREGA EL VALOR DEL',
#                  'CACHORR@ MAS LOS PASAJES ***',
#                  'CL: 09*63*63*0663',
#                  '*** EN QUITO Y ALREDEDORES ENTREGA SIN COSTO ADICIONAL ***',
#                  '------------------------------------------------------------------------------------------------------',
#                  'CADA CACHORRO TIENE UN VALOR DE $200',
#                  'MACHOS',
#                  'HEMBRAS',
#                  'DE DOS MESE DE EDAD',
#                  'PADRE Y MADRE PUROS',
#                  'YA ESTAN VACUNADOS Y',
#                  'DESPARASITADOS',
#                  'YA COMEN SOLO CROQUETAS',
#                  'SE LES DESTETO HACE 15 DIAS',
#                  'TOTALMENTE SANOS Y',
#                  'BIEN CUIDADOS'],
#  'precio': ['1'],
#  'titulo': ['Cachorros Salchicha Teckel A200']}
# 2023-10-27 21:36:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-521593761-shitzu-shih-tzu-shihtzu-mini-350-pureza-garantizada-_JM#position=43&search_layout=stack&type=item&tracking_id=dafa0030-267f-4c5e-baf1-e2cc9458dcd9> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_51_NoIndex_True)
# 2023-10-27 21:36:37 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:56: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('titulo', '//h1/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:37 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:57: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('descripcion', '//div[@class="ui-pdp-description"]/p/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:37 [charset_normalizer] DEBUG: Encoding detection: utf_8 is most likely the one.
# 2023-10-27 21:36:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-521593761-shitzu-shih-tzu-shihtzu-mini-350-pureza-garantizada-_JM>
# {'descripcion': ['PRECIOSURA DE CACHORRITOS SHIH TZU NMACHITOS Y HEMBRITAS '
#                  'VACUNADOS DESPARASITADOS 100% PUROS LÌNEA ARGENTINA TE '
#                  'GARANTIZAMOS SU PUREZA CON UN CERTIFICADO, NO TE LOS PIERDAS '
#                  'TIENEN DOS MESES DE EDAD Y ESTÀN EN TRESCIENTOS CINCUENTA '
#                  'LISTOS AL CERO PARA NUEVE FORMAR OCHO PARTE 50 DE TU FAMILIA '
#                  'SETENTA HAZ CUATRO LAS 18 PREGUNTAS NECESARIAS ANTES DE '
#                  'REALIZAR TU COMPRA ESTAREMOS GUSTOSOS DE PODERTE SERVIR COS '
#                  'LOS CACHORRITOS MÀS LINDOS ÑATOS Y PELUDITOS'],
#  'precio': ['2'],
#  'titulo': ['Shitzu  Shih Tzu  Shihtzu Mini 350 Pureza Garantizada']}
# 2023-10-27 21:36:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-547446622-cachorros-cocker-_JM#position=42&search_layout=stack&type=item&tracking_id=dafa0030-267f-4c5e-baf1-e2cc9458dcd9> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_51_NoIndex_True)
# 2023-10-27 21:36:38 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:56: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('titulo', '//h1/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:38 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:57: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('descripcion', '//div[@class="ui-pdp-description"]/p/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:38 [charset_normalizer] DEBUG: Encoding detection: utf_8 is most likely the one.
# 2023-10-27 21:36:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-547446622-cachorros-cocker-_JM>
# {'descripcion': ['Cachorros cocker, están vacunados y desparasitados, entrego '
#                  'con su carnet de vacunas al día.  Ya comen solo croquetas y '
#                  'están listos para formar parte de una nueva familia. Realizo '
#                  'entregas a domicilio sin recargo adicional en Quito, envíos '
#                  'a todas las provincias del Ecuador y entregas personalizadas '
#                  'puerta a puerta.'],
#  'precio': ['2'],
#  'titulo': ['Cachorros Cocker']}
# 2023-10-27 21:36:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://articulo.mercadolibre.com.ec/MEC-549914518-cada-cachorro-akita-americano-en350-_JM#position=41&search_layout=stack&type=item&tracking_id=dafa0030-267f-4c5e-baf1-e2cc9458dcd9> (referer: https://listado.mercadolibre.com.ec/animales-mascotas/perros/_Desde_51_NoIndex_True)
# 2023-10-27 21:36:39 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:56: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('titulo', '//h1/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:39 [py.warnings] WARNING: /var/folders/5q/75t4z1sd6vg5lq56p9vh1cgm0000gn/T/ipykernel_83055/2482256198.py:57: ScrapyDeprecationWarning: scrapy.loader.processors.MapCompose is deprecated, instantiate itemloaders.processors.MapCompose instead.
#   item.add_xpath('descripcion', '//div[@class="ui-pdp-description"]/p/text()', MapCompose(lambda i: i.replace('\n', ' ').replace('\r', ' ').strip()))
#
# 2023-10-27 21:36:39 [charset_normalizer] DEBUG: Encoding detection: utf_8 is most likely the one.
# 2023-10-27 21:36:39 [scrapy.core.scraper] DEBUG: Scraped from <200 https://articulo.mercadolibre.com.ec/MEC-549914518-cada-cachorro-akita-americano-en350-_JM>
# {'descripcion': ['----------------------------------------------------------------------------------------------------',
#                  '*** ENTREGO PERSONALMENTE EN CUALQUIER CIUDAD DEL PAIS',
#                  'UD CANCELA AL MOMENTO DE LA ENTREGA EL VALOR DEL',
#                  'CACHORR@ MAS LOS PASAJES ***',
#                  'CL: 09*63*63*0663',
#                  '*** EN QUITO Y ALREDEDORES ENTREGA SIN COSTO ADICIONAL ***',
#                  '------------------------------------------------------------------------------------------------------',
#                  'CADA CACHORRO TIENE UN VALOR DE $350',
#                  'MACHOS',
#                  'HEMBRAS',
#                  'DE DOS MESE DE EDAD',
#                  'PADRE Y MADRE PUROS',
#                  'YA ESTAN VACUNADOS Y',
#                  'DESPARASITADOS',
#                  'YA COMEN SOLO CROQUETAS',
#                  'SE LES DESTETO HACE 15 DIAS',
#                  'TOTALMENTE SANOS Y',
#                  'BIEN CUIDADOS'],
#  'precio': ['1'],
#  'titulo': ['Cada Cachorro Akita Americano En350']}
# 2023-10-27 21:36:39 [scrapy.extensions.feedexport] INFO: Stored json feed (33 items) in: ml.json
# 2023-10-27 21:36:39 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 19337,
#  'downloader/request_count': 35,
#  'downloader/request_method_count/GET': 35,
#  'downloader/response_bytes': 3099519,
#  'downloader/response_count': 35,
#  'downloader/response_status_count/200': 35,
#  'dupefilter/filtered': 51,
#  'elapsed_time_seconds': 40.199701,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'closespider_pagecount',
#  'finish_time': datetime.datetime(2023, 10, 27, 19, 36, 39, 699485, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 12240768,
#  'httpcompression/response_count': 35,
#  'item_scraped_count': 33,
#  'log_count/DEBUG': 103,
#  'log_count/INFO': 11,
#  'log_count/WARNING': 68,
#  'memusage/max': 118194176,
#  'memusage/startup': 118194176,
#  'request_depth_max': 3,
#  'response_received_count': 35,
#  'scheduler/dequeued': 35,
#  'scheduler/dequeued/memory': 35,
#  'scheduler/enqueued': 105,
#  'scheduler/enqueued/memory': 105,
#  'start_time': datetime.datetime(2023, 10, 27, 19, 35, 59, 499784, tzinfo=datetime.timezone.utc)}
# 2023-10-27 21:36:39 [scrapy.core.engine] INFO: Spider closed (closespider_pagecount)
