# %%
from scrapy.item import Field
from scrapy.item import Item
from scrapy.spiders import Spider
from scrapy.selector import Selector
from scrapy.loader.processors import MapCompose
from scrapy.loader import ItemLoader
from bs4 import BeautifulSoup
from scrapy.crawler import CrawlerProcess

class Noticia(Item):
    id = Field()
    titular = Field()
    descripcion = Field()

# CLASE CORE - SPIDER 

class ElUniversoSpider(Spider):

    name = "MiSegundoSpider"
    custom_settings = {
        'USER_AGENT': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/71.0.3578.80 Chrome/71.0.3578.80 Safari/537.36',
        # 'FEED_EXPORT_FIELDS': ['id', 'descripcion', 'titular'], # Como ordenar las columnas en el CSV?
        # 'CONCURRENT_REQUESTS': 1 # numero de requerimientos concurrentes
        #'FEED_EXPORT_ENCODING': 'utf-8'
    }

    start_urls = ['https://www.eluniverso.com/deportes']

    def parse(self, response):
        sel = Selector(response)
        noticias = sel.xpath('//div[contains(@class, "content-feed")]/ul/li')
        for i, elem in enumerate(noticias): # PARA INVESTIGAR: Para que sirve enumerate?
            item = ItemLoader(Noticia(), elem) # Cargo mi item
            # Llenando mi item a traves de expresiones XPATH
            item.add_xpath('titular', './/h2/a/text()')
            item.add_xpath('descripcion', './/p/text()')
            item.add_value('id', i)
            yield item.load_item() # Retorno mi item lleno

process = CrawlerProcess({
    'FEED_FORMAT': 'json',
    'FEED_URI': 'datos_de_salida_3.json'
})

process.crawl(ElUniversoSpider)
process.start()
# Out:
# 2023-10-17 08:39:03 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: scrapybot)
# 2023-10-17 08:39:03 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.9.13, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.1, Twisted 22.10.0, Python 3.11.4 (main, Jun 20 2023, 17:23:00) [Clang 14.0.3 (clang-1403.0.22.14.1)], pyOpenSSL 23.2.0 (OpenSSL 3.1.1 30 May 2023), cryptography 41.0.1, Platform macOS-13.4.1-arm64-arm-64bit
# 2023-10-17 08:39:03 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-10-17 08:39:03 [py.warnings] WARNING: /opt/homebrew/lib/python3.11/site-packages/scrapy/utils/request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-10-17 08:39:03 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-10-17 08:39:03 [scrapy.extensions.telnet] INFO: Telnet Password: 3a3d257ecb87d0a6
# 2023-10-17 08:39:03 [py.warnings] WARNING: /opt/homebrew/lib/python3.11/site-packages/scrapy/extensions/feedexport.py:406: ScrapyDeprecationWarning: The `FEED_URI` and `FEED_FORMAT` settings have been deprecated in favor of the `FEEDS` setting. Please see the `FEEDS` setting docs for more details
#   exporter = cls(crawler)
#
# 2023-10-17 08:39:03 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2023-10-17 08:39:03 [scrapy.crawler] INFO: Overridden settings:
# {'USER_AGENT': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, '
#                'like Gecko) Ubuntu Chromium/71.0.3578.80 Chrome/71.0.3578.80 '
#                'Safari/537.36'}
# 2023-10-17 08:39:03 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-10-17 08:39:03 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-10-17 08:39:03 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-10-17 08:39:03 [scrapy.core.engine] INFO: Spider opened
# 2023-10-17 08:39:03 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-10-17 08:39:03 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-10-17 08:39:03 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.eluniverso.com/deportes/> from <GET https://www.eluniverso.com/deportes>
# 2023-10-17 08:39:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.eluniverso.com/deportes/> (referer: None)
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'descripcion': ['Aunque llegó hace poco, el ecuatoriano se ha hecho un hueco '
#                  'muy rápido en el equipo que defiende el título logrado la '
#                  'temporada pasada.'],
#  'id': [0],
#  'titular': ['Diego Almeida, campeón con Columbus Crew 2 de la Conferencia '
#              'Oeste de la MLS Next Pro']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'descripcion': ['Uno de los puntos tratados favorece a los cafeteros. Se '
#                  'vuelve a tocar el tema de la goleada 6-1 con la que la '
#                  'Tricolor castigó a su rival hace tres años.'],
#  'id': [1],
#  'titular': ['La selección de Ecuador y sus ‘piedras preciosas’, entre las '
#              'tres claves para el  juego contra Colombia, según un análisis de '
#              'AFP']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'descripcion': ['Antes del partido del martes, por las eliminatorias al '
#                  'Mundial 2026, los medios de comunicación recuerdan, en '
#                  'varias notas, la goleada sufrida en el 2020.'],
#  'id': [2],
#  'titular': ['¿No hay trauma? ‘Los fantasmas de Quito que asustan a Colombia’ '
#              'y ‘Después del desastroso 6-1 estos son los jugadores que '
#              'repiten ante Ecuador’, dice la prensa cafetera']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'descripcion': ['Ejemplar argentino, muy bien corrido por Jofre Mora, marcó '
#                  'un tiempo final  de 1 min 21,07 s.'],
#  'id': [3],
#  'titular': ['Nightwish ganó clásico hípico en prueba que se corrió sobre '
#              '1.300 metros']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'descripcion': ['El 17 de noviembre de 2020 la Tri bailó a los cafeteros y '
#                  'este martes vuelven a medirse en el mismo estadio Rodrigo '
#                  'Paz Delgado por eliminatorias mundialistas.'],
#  'id': [4],
#  'titular': ['‘Lo pasado, pasado’. ¿Cuántos jugadores repiten en Ecuador a '
#              'tres años del 6-1 ante Colombia?']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'descripcion': ['Un colorido altar tradicional fue levantado a un lado del '
#                  'estadio Nacional con amuletos, espadas, banderas de ambas '
#                  'selecciones.'],
#  'id': [5],
#  'titular': ['Brujos de Perú también juegan en las eliminatorias '
#              'sudamericanas: hicieron ritual para anular a Lionel Messi en el '
#              'partido ante Argentina']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'descripcion': ['El astro luso llegó a los 40 goles y superó al noruego '
#                  'Erling Haaland como máximo artillero en lo que va del 2023.'],
#  'id': [6],
#  'titular': ['¡Imparable! Cristiano Ronaldo anota un doblete para Portugal y '
#              'se convierte en el máximo goleador del 2023']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'descripcion': ['El partido entre Bélgica y Suecia se suspendió al culminar '
#                  'el primer tiempo.'],
#  'id': [7],
#  'titular': ['Al grito de ‘Alá es grande’ asesinan a dos personas en la '
#              'capital de Bélgica, agresor sigue libre']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'descripcion': ['La Tri prefiere no llorar sobre la leche derramada. Los '
#                  'jugadores “siguen con energía y los chicos quieren más y esa '
#                  'es la mentalidad correcta”.'],
#  'id': [8],
#  'titular': ['Selección de Ecuador estaría en la zona de clasificación al '
#              'Mundial 2026 si el TAS no lo hubiera castigado por el caso de '
#              'Byron Castillo ']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'descripcion': ['El triunfo ecuatoriano en La Paz hace respirar más tranquila '
#                  'a la ‘Tri’, ya que su casillero figura en positivo luego de '
#                  'comenzar la eliminatoria con -3 puntos.'],
#  'id': [9],
#  'titular': ['Ecuador vs. Colombia por las eliminatorias sudamericanas: '
#              'canales de TV y streaming para ver en vivo']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'descripcion': ['El colegiado argentino cuenta con un antecedente no tan '
#                  'positivo dirigiendo los partidos de la Tricolor en las '
#                  'eliminatorias sudamericanas.'],
#  'id': [10],
#  'titular': ['¿Cómo le fue a la selección ecuatoriana en los partidos que la '
#              'dirigió Facundo Tello, árbitro designado para el duelo ante '
#              'Colombia por las eliminatorias?']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'descripcion': ['Ecuafútbol puso a la venta boletos\xa0que fueron liberados '
#                  "en la plataforma 'FanFEF'\xa0para el juego de la cuarta "
#                  'fecha de la eliminatoria mundialista.'],
#  'id': [11],
#  'titular': ['¡Última oportunidad! Remanente de entradas disponibles para el '
#              'Ecuador vs. Colombia']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'descripcion': ['Con tres triunfos y puntaje perfecto, Argentina se ubica con '
#                  'nueve puntos en el primer lugar del premundial seguido por '
#                  'Brasil y Colombia con 7 y 5 unidades.'],
#  'id': [12],
#  'titular': ['Perú vs. Argentina por las eliminatorias sudamericanas: horarios '
#              'y streaming para ver en vivo']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'descripcion': ['Hasta el momento solo el empresario Rafael Verduga ha hecho '
#                  'oficial su candidatura a la presidencia del cuadro canario.'],
#  'id': [13],
#  'titular': ['¡Ya hay fecha! Elecciones para la presidencia de Barcelona SC se '
#              'realizarán en noviembre']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'descripcion': ['Brasil cedió así la punta de la clasificatoria ante una '
#                  'Argentina con puntaje perfecto (9 puntos), al tiempo que '
#                  'Uruguay se mantuvo en cuarta posición (4).'],
#  'id': [14],
#  'titular': ['Uruguay vs. Brasil por las eliminatorias sudamericanas: horarios '
#              'y streaming para ver en vivo']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [15], 'titular': ['Dos arriba y dos abajo']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [16], 'titular': ['El Mundial 2030: las ilusiones defraudadas']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [17], 'titular': ['Ya ni la altura nos queda…']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [18],
#  'titular': ['John Yeboah Zamora en la selección de Ecuador: los factores '
#              'positivos y negativos de su convocatoria']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [19], 'titular': ['Para ganar necesita empatar']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [20],
#  'titular': ['‘Se contrató a un flojonazo’, el palazo de la prensa de Bolivia '
#              'a Gustavo Costas, un ‘DT por accidente’, tras la derrota ante '
#              'Ecuador en la eliminatoria 2026']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [21],
#  'titular': ['‘¡Moisés Ramírez, titular! Eso evidencia que Félix Sánchez Bas '
#              'tiene, en la selección de Ecuador, pocas posibilidades de tomar '
#              'decisiones’, dice Carlos Torres Garcés']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [22],
#  'titular': ['La selección de Ecuador y sus ‘piedras preciosas’, entre las '
#              'tres claves para el  juego contra Colombia, según un análisis de '
#              'AFP']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [23],
#  'titular': ['¿De cuánto es la fortuna de Michael Jordan? Estos son los cinco '
#              'negocios menos conocidos del rey de la NBA que bate un nuevo '
#              'récord con su milmillonario patrimonio']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [24],
#  'titular': ['James Rodríguez, ¿ausente en Colombia para medir a Ecuador por '
#              'eliminatoria sudamericana 2026?']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [25],
#  'titular': ['¡Ya hay fecha! Elecciones para la presidencia de Barcelona SC se '
#              'realizarán en noviembre']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [26], 'titular': ['La columna de Bonil']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [27], 'titular': ['El poder del fútbol se requiere para el país']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [28],
#  'titular': ['Bucaram, sobre el abrazo con Nebot: A la hinchada le dio alegría '
#              'ver a dos líderes políticos barcelonistas dando un ejemplo de '
#              'desprendimiento, de madurez']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [29],
#  'titular': ['Abdalá Bucaram: ‘¿Y ahora? Yo quería ser campeón del mundo con '
#              'Barcelona SC con Diego Maradona, Batistuta, Caniggia y '
#              'Valderrama, pero por esta pica y envidia me derrocaron de la '
#              'Presidencia de Ecuador’']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [30],
#  'titular': ['Gustavo Quinteros, extécnico de Emelec, y su estallido de furia '
#              'con un periodista en Chile: ¡No preguntes tonterías!']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [31],
#  'titular': ['FIFA obliga a pagar a Emelec por ‘incumplimiento de contrato’ '
#              'con Leandro Vega']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [32],
#  'titular': ['‘Nos vamos a jugar la vida, no podemos relajarnos’, advierte '
#              'Hernán Torres, DT de Emelec, tras triunfo frente a Cumbayá FC '
#              'por la Liga Pro']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [33],
#  'titular': ['Así queda la tabla de posiciones con el tropiezo de Barcelona SC '
#              'en Quito']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [34],
#  'titular': ['¡Goleada azul! Emelec supera a Cumbayá FC y se aleja del peligro '
#              'de descender']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [35],
#  'titular': ['¿Cuándo salen a la venta los boletos para los hinchas de Liga de '
#              'Quito para la final de la Copa Sudamericana ante Fortaleza en '
#              'Uruguay?']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [36],
#  'titular': ['Luis Zubeldía: La cancha del Jocay es la peor, no favorece al '
#              'espectáculo']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [37],
#  'titular': ["En Inglaterra quieren a Óscar Zambrano, el 'nuevo Moisés "
#              "Caicedo'"]}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [38],
#  'titular': ['Tabla de posiciones: Barcelona SC mantiene el liderato en la '
#              'segunda etapa de la Liga Pro']}
# 2023-10-17 08:39:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.eluniverso.com/deportes/>
# {'id': [39],
#  'titular': ['Delfín SC y Liga de Quito empatan y frenan su marcha al '
#              'liderato']}
# 2023-10-17 08:39:03 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-10-17 08:39:03 [scrapy.extensions.feedexport] INFO: Stored json feed (40 items) in: datos_de_salida_3.json
# 2023-10-17 08:39:03 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 669,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 174374,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 1,
#  'downloader/response_status_count/301': 1,
#  'elapsed_time_seconds': 0.430828,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 10, 17, 6, 39, 3, 900247, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 1354352,
#  'httpcompression/response_count': 1,
#  'item_scraped_count': 40,
#  'log_count/DEBUG': 43,
#  'log_count/INFO': 11,
#  'log_count/WARNING': 2,
#  'memusage/max': 109232128,
#  'memusage/startup': 109232128,
#  'response_received_count': 1,
#  'scheduler/dequeued': 2,
#  'scheduler/dequeued/memory': 2,
#  'scheduler/enqueued': 2,
#  'scheduler/enqueued/memory': 2,
#  'start_time': datetime.datetime(2023, 10, 17, 6, 39, 3, 469419, tzinfo=datetime.timezone.utc)}
# 2023-10-17 08:39:03 [scrapy.core.engine] INFO: Spider closed (finished)
